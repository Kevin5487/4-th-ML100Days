# %%
#1-1
import numpy as np
import matplotlib.pyplot as plt
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
# 上面的 'b.' 是藍色點狀, 下面的 'r-' 是紅色線狀, label 是圖示上的名稱
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
def mean_square_error(y, yp):
   
    mse = MSE = np.mean((y - yp)**2)#np.mean計算矩陣均值
    return mse

MAE = mean_absolute_error(y, y_hat)
MSE = mean_square_error(y, y_hat)
print("The Mean absolute error is %.3f" %(MAE))#％.3f表示將區域打印爲浮點小數點，精度至少爲3位數
print("The Mean squared error is %.3f" %(MSE))
# Out:
# The Mean absolute error is 12.157
# The Mean squared error is 228.419

# %%
#1-2
#Hotel Booking Demand on Kaggle
#網址:https://www.kaggle.com/jessemostipak/hotel-booking-demand
# 1. 你選的這組資料為何重要
     #對想要旅遊訂飯店或是短期住宿的人來說，可以在訂位時找到最划算以及最佳的時間點

# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
     #The data is originally from the article Hotel Booking Demand Datasets, 
     #written by Nuno Antonio, Ana Almeida, and Luis Nunes for Data in Brief, Volume 22, February 2019.

# 3. 蒐集而來的資料型態為何
     #數值,表格

# 4. 這組資料想解決的問題如何評估
     #數值大小 用百分比與長條圖表示

#1-3
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
     #透過分配不同數量的司機於不同地點(最熱門地點分配最多司機)達到最大載客量，提升業績

# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
     #利用gps及時回傳路線圖分析每趟單的地點分布

# 3. 蒐集而來的資料型態為何
     #圖片(地圖),數字(經緯度),文字(地名)

# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
     #分配後的總單數是否有成長
